# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import pandas as pd
from sksurv.svm import FastKernelSurvivalSVM
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sksurv.metrics import concordance_index_censored, integrated_brier_score, brier_score
from lifelines.utils.sklearn_adapter import sklearn_adapter
from lifelines.utils import concordance_index
from scipy.stats import gumbel_r, norm, logistic
import lifelines.datasets as dset
import math
from sklearn.calibration import calibration_curve, CalibrationDisplay
from matplotlib.gridspec import GridSpec
import warnings
from scipy.special import erf
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torchtuples as tt

from pycox.preprocessing.label_transforms import LabTransDiscreteTime
from pycox.models import DeepHit
from pycox.evaluation import EvalSurv
import pandas as pd
import numpy as np
import os,sys
sys.path.append("../")
from dirac_phi import DiracPhi
from survival import MixExpPhiStochastic,InnerGenerator,InnerGenerator2,sample,HACSurv_3D_Sym_shared
import torch.optim as optim
import torch
from tqdm import tqdm


# 固定随机数种子
np.random.seed(42)

df = pd.read_csv('./mimic_time_data_withoutETT.csv')

# 数据分割
df_test = df.sample(frac=0.2, random_state=42)
df_train = df.drop(df_test.index)
df_val = df_train.sample(frac=0.2, random_state=42)
df_train = df_train.drop(df_val.index)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# 提取特征
x_train = df_train.drop(columns=['time', 'death_reason', 'label']).values.astype('float32')
x_val = df_val.drop(columns=['time', 'death_reason', 'label']).values.astype('float32')
x_test = df_test.drop(columns=['time', 'death_reason', 'label']).values.astype('float32')

# 提取时间和事件标签
get_target = lambda df: (df['time'].values, df['death_reason'].values)
time_train, event_train = get_target(df_train)
time_val, event_val = get_target(df_val)
time_test, event_test = get_target(df_test)

# 将数据转换为张量，并移动到指定设备上（GPU或CPU）
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

covariate_tensor_train = torch.tensor(x_train, dtype=torch.float64).to(device)
covariate_tensor_val = torch.tensor(x_val, dtype=torch.float64).to(device)
covariate_tensor_test = torch.tensor(x_test, dtype=torch.float64).to(device)

times_tensor_train = torch.tensor(time_train, dtype=torch.float64).to(device)
event_indicator_tensor_train = torch.tensor(event_train, dtype=torch.float64).to(device)

times_tensor_val = torch.tensor(time_val, dtype=torch.float64).to(device)
event_indicator_tensor_val = torch.tensor(event_val, dtype=torch.float64).to(device)

times_tensor_test = torch.tensor(time_test, dtype=torch.float64).to(device)
event_indicator_tensor_test = torch.tensor(event_test, dtype=torch.float64).to(device)

# print(covariate_tensor_val)
torch.set_num_threads(16)
torch.set_default_tensor_type(torch.DoubleTensor)
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

num_epochs = 100000
batch_size = 300
early_stop_epochs = 1500

selected_indicators = [1,3,5]

model_dir = './MIMIC-III/checkpoint'
figures_dir = './MIMIC-III/figure'

phi = MixExpPhiStochastic(device)
model =HACSurv_3D_Sym_shared(phi, device = device, num_features=x_train.shape[1], tol=1e-14, hidden_size = 100).to(device)
optimizer = optim.AdamW([{"params": model.sumo_e1.parameters(), "lr": 1e-4},
                         {"params": model.sumo_e2.parameters(), "lr": 1e-4},
                        {"params": model.sumo_c.parameters(), "lr": 1e-4},
                        # {"params": model.phi.parameters(), "lr": 3e-4}
                        {"params": model.phi.parameters(), "lr": 2e-4}
                    ])

best_val_loglikelihood = float('-inf')
epochs_no_improve = 0
# for epoch in tqdm(range(num_epochs)):
for epoch in range(num_epochs):
    optimizer.zero_grad()
    model.phi.resample_M(200)
    logloss = model(covariate_tensor_train, times_tensor_train, event_indicator_tensor_train, max_iter = 10000,selected_indicators=[1,3,5])
    # scaleloss = torch.square(torch.mean(model.phi.M)-1)
    # reg_loss = logloss+scaleloss
    (-logloss).backward() 
    optimizer.step()
    if epoch % 100 == 0 and epoch > 0:
        # Validation and logging
        print("Epoch", epoch, "Train loglikelihood:", logloss.item())
        model.phi.resample_M(200)
        val_loglikelihood = model(covariate_tensor_val, times_tensor_val, event_indicator_tensor_val, max_iter=10000,selected_indicators=[1,3,5])
        print("Validation likelihood:", val_loglikelihood.item())

        # Model checkpointing
        if val_loglikelihood > best_val_loglikelihood:
            best_val_loglikelihood = val_loglikelihood
            epochs_no_improve = 0
            indicators_str = ''.join(map(str, selected_indicators))
            checkpoint_path = os.path.join(model_dir, f'MIMIC_e135_sharedHACSurv.pth')
            torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'loss': best_val_loglikelihood}, checkpoint_path)

            # Generate and save plots
            print('Scatter sampling')
            samples = sample(model, 2, 2000, device=device)
            plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu(), s=15)
            plot_path = os.path.join(figures_dir, f'MIMIC_e135_sharedHACSurv.png')
            plt.savefig(plot_path)
            plt.clf()

        else:
            epochs_no_improve += 100

        # Early stopping condition
        if epochs_no_improve >= early_stop_epochs:
            print('Early stopping triggered at epoch:', epoch)
            break
# Out:
# Epoch 100 Train loglikelihood: -40505.15495092473
# Validation likelihood: -9898.372913866388
# Scatter sampling
# Sampling from dim: 1
# Epoch 200 Train loglikelihood: -33856.54557412451
# Validation likelihood: -8503.786815441183
# Scatter sampling
# Sampling from dim: 1
# Epoch 300 Train loglikelihood: -29735.021735904418
# Validation likelihood: -7484.613893502482
# Scatter sampling
# Sampling from dim: 1
# Epoch 400 Train loglikelihood: -23328.427001659595
# Validation likelihood: -5833.037466623371
# Scatter sampling
# Sampling from dim: 1
# Epoch 500 Train loglikelihood: -16115.06751842512
# Validation likelihood: -4056.2389932412666
# Scatter sampling
# Sampling from dim: 1
# Epoch 600 Train loglikelihood: -13236.004046969005
# Validation likelihood: -3345.1118275094623
# Scatter sampling
# Sampling from dim: 1
# Epoch 700 Train loglikelihood: -11726.61714453782
# Validation likelihood: -2949.408806550214
# Scatter sampling
# Sampling from dim: 1
# Epoch 800 Train loglikelihood: -11379.137098943957
# Validation likelihood: -2862.580694293123
# Scatter sampling
# Sampling from dim: 1
# Epoch 900 Train loglikelihood: -11157.521479379706
# Validation likelihood: -2807.1454296680904
# Scatter sampling
# Sampling from dim: 1
# Epoch 1000 Train loglikelihood: -10972.179506578901
# Validation likelihood: -2759.0323987563797
# Scatter sampling
# Sampling from dim: 1
# Epoch 1100 Train loglikelihood: -10801.000318365435
# Validation likelihood: -2713.782145662481
# Scatter sampling
# Sampling from dim: 1
# Epoch 1200 Train loglikelihood: -10636.090533726934
# Validation likelihood: -2670.225343549543
# Scatter sampling
# Sampling from dim: 1
# Epoch 1300 Train loglikelihood: -10475.50457393282
# Validation likelihood: -2628.158531150395
# Scatter sampling
# Sampling from dim: 1
# Epoch 1400 Train loglikelihood: -10322.739614908474
# Validation likelihood: -2588.686272310976
# Scatter sampling
# Sampling from dim: 1
# Epoch 1500 Train loglikelihood: -10193.084808041105
# Validation likelihood: -2555.8807613092467
# Scatter sampling
# Sampling from dim: 1
# Epoch 1600 Train loglikelihood: -10108.850697378854
# Validation likelihood: -2534.309903370632
# Scatter sampling
# Sampling from dim: 1
# Epoch 1700 Train loglikelihood: -10065.087799789482
# Validation likelihood: -2521.8363771764034
# Scatter sampling
# Sampling from dim: 1
# Epoch 1800 Train loglikelihood: -10027.980458377517
# Validation likelihood: -2512.1630428634235
# Scatter sampling
# Sampling from dim: 1
# Epoch 1900 Train loglikelihood: -10001.716538436569
# Validation likelihood: -2506.9488358120025
# Scatter sampling
# Sampling from dim: 1
# Epoch 2000 Train loglikelihood: -9980.884918678654
# Validation likelihood: -2502.392907480342
# Scatter sampling
# Sampling from dim: 1
# Epoch 2100 Train loglikelihood: -9961.920856374842
# Validation likelihood: -2497.7953723732808
# Scatter sampling
# Sampling from dim: 1
# Epoch 2200 Train loglikelihood: -9943.503840264397
# Validation likelihood: -2492.9774956984916
# Scatter sampling
# Sampling from dim: 1
# Epoch 2300 Train loglikelihood: -9924.82819141208
# Validation likelihood: -2487.899602820299
# Scatter sampling
# Sampling from dim: 1
# Epoch 2400 Train loglikelihood: -9906.708728606089
# Validation likelihood: -2483.1525479378033
# Scatter sampling
# Sampling from dim: 1
# Epoch 2500 Train loglikelihood: -9887.611223835866
# Validation likelihood: -2478.6590765325986
# Scatter sampling
# Sampling from dim: 1
# Epoch 2600 Train loglikelihood: -9864.637705080284
# Validation likelihood: -2473.0782063692886
# Scatter sampling
# Sampling from dim: 1
# Epoch 2700 Train loglikelihood: -9843.41019406268
# Validation likelihood: -2467.64253991058
# Scatter sampling
# Sampling from dim: 1
# Epoch 2800 Train loglikelihood: -9821.859092816132
# Validation likelihood: -2462.5693599070355
# Scatter sampling
# Sampling from dim: 1
# Epoch 2900 Train loglikelihood: -9799.558957552632
# Validation likelihood: -2457.5215369026328
# Scatter sampling
# Sampling from dim: 1
# Epoch 3000 Train loglikelihood: -9776.365667058191
# Validation likelihood: -2452.3730102162554
# Scatter sampling
# Sampling from dim: 1
# Epoch 3100 Train loglikelihood: -9752.427418481948
# Validation likelihood: -2447.160276330254
# Scatter sampling
# Sampling from dim: 1
# Epoch 3200 Train loglikelihood: -9728.08089666681
# Validation likelihood: -2441.9594236845733
# Scatter sampling
# Sampling from dim: 1
# Epoch 3300 Train loglikelihood: -9704.965024252935
# Validation likelihood: -2437.220538887218
# Scatter sampling
# Sampling from dim: 1
# Epoch 3400 Train loglikelihood: -9683.819093306965
# Validation likelihood: -2433.2563549547776
# Scatter sampling
# Sampling from dim: 1
# Epoch 3500 Train loglikelihood: -9664.447911660953
# Validation likelihood: -2429.715471778063
# Scatter sampling
# Sampling from dim: 1
# Epoch 3600 Train loglikelihood: -9646.448687338274
# Validation likelihood: -2426.4475008688964
# Scatter sampling
# Sampling from dim: 1
# Epoch 3700 Train loglikelihood: -9629.181588623882
# Validation likelihood: -2423.34660334169
# Scatter sampling
# Sampling from dim: 1
# Epoch 3800 Train loglikelihood: -9612.352335032316
# Validation likelihood: -2420.116301031117
# Scatter sampling
# Sampling from dim: 1
# Epoch 3900 Train loglikelihood: -9595.807898244348
# Validation likelihood: -2417.0313377616776
# Scatter sampling
# Sampling from dim: 1
# Epoch 4000 Train loglikelihood: -9579.522942991114
# Validation likelihood: -2414.0061347822284
# Scatter sampling
# Sampling from dim: 1
# Epoch 4100 Train loglikelihood: -9563.507681320612
# Validation likelihood: -2411.083925768066
# Scatter sampling
# Sampling from dim: 1
# Epoch 4200 Train loglikelihood: -9547.843634933428
# Validation likelihood: -2408.3066900678646
# Scatter sampling
# Sampling from dim: 1
# Epoch 4300 Train loglikelihood: -9532.538730319033
# Validation likelihood: -2405.728893196463
# Scatter sampling
# Sampling from dim: 1
# Epoch 4400 Train loglikelihood: -9517.547155974737
# Validation likelihood: -2403.081363098797
# Scatter sampling
# Sampling from dim: 1
# Epoch 4500 Train loglikelihood: -9502.807729961816
# Validation likelihood: -2400.5847134363175
# Scatter sampling
# Sampling from dim: 1
# Epoch 4600 Train loglikelihood: -9488.232629317752
# Validation likelihood: -2397.886969197983
# Scatter sampling
# Sampling from dim: 1
# Epoch 4700 Train loglikelihood: -9473.849952980265
# Validation likelihood: -2395.034352166991
# Scatter sampling
# Sampling from dim: 1
# Epoch 4800 Train loglikelihood: -9459.570161450176
# Validation likelihood: -2391.9830143403606
# Scatter sampling
# Sampling from dim: 1
# Epoch 4900 Train loglikelihood: -9445.203024603
# Validation likelihood: -2388.708481990803
# Scatter sampling
# Sampling from dim: 1
# Epoch 5000 Train loglikelihood: -9430.556734011212
# Validation likelihood: -2385.284935274029
# Scatter sampling
# Sampling from dim: 1
# Epoch 5100 Train loglikelihood: -9415.678974139066
# Validation likelihood: -2381.791722406744
# Scatter sampling
# Sampling from dim: 1
# Epoch 5200 Train loglikelihood: -9400.492639396445
# Validation likelihood: -2378.1598107284062
# Scatter sampling
# Sampling from dim: 1
# Epoch 5300 Train loglikelihood: -9384.82518317725
# Validation likelihood: -2374.4083844033166
# Scatter sampling
# Sampling from dim: 1
# Epoch 5400 Train loglikelihood: -9368.667849426063
# Validation likelihood: -2370.5540455116948
# Scatter sampling
# Sampling from dim: 1
# Epoch 5500 Train loglikelihood: -9351.979513892866
# Validation likelihood: -2366.548424648832
# Scatter sampling
# Sampling from dim: 1
# Epoch 5600 Train loglikelihood: -9334.663510366283
# Validation likelihood: -2362.3449915039323
# Scatter sampling
# Sampling from dim: 1
# Epoch 5700 Train loglikelihood: -9316.667754097607
# Validation likelihood: -2357.9017443309476
# Scatter sampling
# Sampling from dim: 1
# Epoch 5800 Train loglikelihood: -9297.951637773704
# Validation likelihood: -2353.2648868606193
# Scatter sampling
# Sampling from dim: 1
# Epoch 5900 Train loglikelihood: -9277.860962173992
# Validation likelihood: -2348.130045840164
# Scatter sampling
# Sampling from dim: 1
# Epoch 6000 Train loglikelihood: -9256.03074581417
# Validation likelihood: -2342.3872595107605
# Scatter sampling
# Sampling from dim: 1
# Epoch 6100 Train loglikelihood: -9231.820721899054
# Validation likelihood: -2335.854032805508
# Scatter sampling
# Sampling from dim: 1
# Epoch 6200 Train loglikelihood: -9204.42700934691
# Validation likelihood: -2328.324497771556
# Scatter sampling
# Sampling from dim: 1
# Epoch 6300 Train loglikelihood: -9172.471231723619
# Validation likelihood: -2319.4871914040764
# Scatter sampling
# Sampling from dim: 1
# Epoch 6400 Train loglikelihood: -9134.089260878676
# Validation likelihood: -2308.739923778118
# Scatter sampling
# Sampling from dim: 1
# Epoch 6500 Train loglikelihood: -9087.461388961867
# Validation likelihood: -2295.7336363609247
# Scatter sampling
# Sampling from dim: 1
# Epoch 6600 Train loglikelihood: -9031.418554001146
# Validation likelihood: -2280.6568718225835
# Scatter sampling
# Sampling from dim: 1
# Epoch 6700 Train loglikelihood: -8966.578279981004
# Validation likelihood: -2263.4640293836014
# Scatter sampling
# Sampling from dim: 1
# Epoch 6800 Train loglikelihood: -8894.399249524626
# Validation likelihood: -2244.360035570692
# Scatter sampling
# Sampling from dim: 1
# Epoch 6900 Train loglikelihood: -8819.882666780264
# Validation likelihood: -2224.7596093576526
# Scatter sampling
# Sampling from dim: 1
# Epoch 7000 Train loglikelihood: -8745.558858290991
# Validation likelihood: -2206.517245259158
# Scatter sampling
# Sampling from dim: 1
# Epoch 7100 Train loglikelihood: -8671.973507046217
# Validation likelihood: -2188.2527590124155
# Scatter sampling
# Sampling from dim: 1
# Epoch 7200 Train loglikelihood: -8604.520738531215
# Validation likelihood: -2170.9642102333955
# Scatter sampling
# Sampling from dim: 1
# Epoch 7300 Train loglikelihood: -8541.698367524608
# Validation likelihood: -2154.4451753998906
# Scatter sampling
# Sampling from dim: 1
# Epoch 7400 Train loglikelihood: -8482.615844675824
# Validation likelihood: -2138.9715117224077
# Scatter sampling
# Sampling from dim: 1
# Epoch 7500 Train loglikelihood: -8426.82901605362
# Validation likelihood: -2124.6905134946096
# Scatter sampling
# Sampling from dim: 1
# Epoch 7600 Train loglikelihood: -8373.90855400851
# Validation likelihood: -2111.289843063442
# Scatter sampling
# Sampling from dim: 1
# Epoch 7700 Train loglikelihood: -8323.738743989448
# Validation likelihood: -2098.7024654006127
# Scatter sampling
# Sampling from dim: 1
# Epoch 7800 Train loglikelihood: -8275.97606205438
# Validation likelihood: -2086.7793355226213
# Scatter sampling
# Sampling from dim: 1
# Epoch 7900 Train loglikelihood: -8230.149430495141
# Validation likelihood: -2075.401906074956
# Scatter sampling
# Sampling from dim: 1
# Epoch 8000 Train loglikelihood: -8186.036605524281
# Validation likelihood: -2064.5895273810506
# Scatter sampling
# Sampling from dim: 1
# Epoch 8100 Train loglikelihood: -8142.204973575395
# Validation likelihood: -2054.7936125338933
# Scatter sampling
# Sampling from dim: 1
# Epoch 8200 Train loglikelihood: -8098.708909255415
# Validation likelihood: -2045.23632562877
# Scatter sampling
# Sampling from dim: 1
# Epoch 8300 Train loglikelihood: -8057.7412706785835
# Validation likelihood: -2035.0776763326078
# Scatter sampling
# Sampling from dim: 1
# Epoch 8400 Train loglikelihood: -8017.894076964765
# Validation likelihood: -2025.3559066801101
# Scatter sampling
# Sampling from dim: 1
# Epoch 8500 Train loglikelihood: -7979.228654473103
# Validation likelihood: -2015.8800594183397
# Scatter sampling
# Sampling from dim: 1
# Epoch 8600 Train loglikelihood: -7941.603870725369
# Validation likelihood: -2006.633513677244
# Scatter sampling
# Sampling from dim: 1
# Epoch 8700 Train loglikelihood: -7904.9344610281405
# Validation likelihood: -1997.580168658968
# Scatter sampling
# Sampling from dim: 1
# Epoch 8800 Train loglikelihood: -7869.136388545263
# Validation likelihood: -1988.6868273602436
# Scatter sampling
# Sampling from dim: 1
# Epoch 8900 Train loglikelihood: -7834.139896051046
# Validation likelihood: -1979.9036999801096
# Scatter sampling
# Sampling from dim: 1
# Epoch 9000 Train loglikelihood: -7799.910490159246
# Validation likelihood: -1971.1135292708923
# Scatter sampling
# Sampling from dim: 1
# Epoch 9100 Train loglikelihood: -7766.56252160746
# Validation likelihood: -1962.021704605988
# Scatter sampling
# Sampling from dim: 1
# Epoch 9200 Train loglikelihood: -7735.268545758839
# Validation likelihood: -1953.212303518045
# Scatter sampling
# Sampling from dim: 1
# Epoch 9300 Train loglikelihood: -7708.234338475683
# Validation likelihood: -1944.5933490732637
# Scatter sampling
# Sampling from dim: 1
# Epoch 9400 Train loglikelihood: -7676.783436582198
# Validation likelihood: -1938.1753966140082
# Scatter sampling
# Sampling from dim: 1
# Epoch 9500 Train loglikelihood: -7636.98741565212
# Validation likelihood: -1929.2865605401714
# Scatter sampling
# Sampling from dim: 1
# Epoch 9600 Train loglikelihood: -7605.596122241786
# Validation likelihood: -1920.0231009737342
# Scatter sampling
# Sampling from dim: 1
# Epoch 9700 Train loglikelihood: -7574.685770807772
# Validation likelihood: -1911.9423545956581
# Scatter sampling
# Sampling from dim: 1
# Epoch 9800 Train loglikelihood: -7543.881617750362
# Validation likelihood: -1904.000155227321
# Scatter sampling
# Sampling from dim: 1
# Epoch 9900 Train loglikelihood: -7513.255488413515
# Validation likelihood: -1896.2002985368883
# Scatter sampling
# Sampling from dim: 1
# Epoch 10000 Train loglikelihood: -7482.476868733319
# Validation likelihood: -1888.6416523923858
# Scatter sampling
# Sampling from dim: 1
# Epoch 10100 Train loglikelihood: -7451.537104186321
# Validation likelihood: -1881.354977808522
# Scatter sampling
# Sampling from dim: 1
# Epoch 10200 Train loglikelihood: -7421.69956228426
# Validation likelihood: -1873.3955868407677
# Scatter sampling
# Sampling from dim: 1
# Epoch 10300 Train loglikelihood: -7392.192147805441
# Validation likelihood: -1865.5868854614178
# Scatter sampling
# Sampling from dim: 1
# Epoch 10400 Train loglikelihood: -7363.08046143738
# Validation likelihood: -1857.996431334749
# Scatter sampling
# Sampling from dim: 1
# Epoch 10500 Train loglikelihood: -7334.245502663969
# Validation likelihood: -1850.4520552243898
# Scatter sampling
# Sampling from dim: 1
# Epoch 10600 Train loglikelihood: -7305.694556390859
# Validation likelihood: -1842.9720335686375
# Scatter sampling
# Sampling from dim: 1
# Epoch 10700 Train loglikelihood: -7277.444505327545
# Validation likelihood: -1835.5699608649102
# Scatter sampling
# Sampling from dim: 1
# Epoch 10800 Train loglikelihood: -7249.4070439491115
# Validation likelihood: -1828.256107682476
# Scatter sampling
# Sampling from dim: 1
# Epoch 10900 Train loglikelihood: -7220.815710331505
# Validation likelihood: -1820.9981980320258
# Scatter sampling
# Sampling from dim: 1
# Epoch 11000 Train loglikelihood: -7193.44690960797
# Validation likelihood: -1813.8363425686812
# Scatter sampling
# Sampling from dim: 1
# Epoch 11100 Train loglikelihood: -7166.541948514388
# Validation likelihood: -1806.7999548070754
# Scatter sampling
# Sampling from dim: 1
# Epoch 11200 Train loglikelihood: -7140.047770544742
# Validation likelihood: -1799.9106421739193
# Scatter sampling
# Sampling from dim: 1
# Epoch 11300 Train loglikelihood: -7113.945612977857
# Validation likelihood: -1793.1770629485338
# Scatter sampling
# Sampling from dim: 1
# Epoch 11400 Train loglikelihood: -7088.248159391994
# Validation likelihood: -1786.5808561365716
# Scatter sampling
# Sampling from dim: 1
# Epoch 11500 Train loglikelihood: -7062.944313378533
# Validation likelihood: -1780.1257474454774
# Scatter sampling
# Sampling from dim: 1
# Epoch 11600 Train loglikelihood: -7038.019479288386
# Validation likelihood: -1773.7907905093539
# Scatter sampling
# Sampling from dim: 1
# Epoch 11700 Train loglikelihood: -7013.4644758583745
# Validation likelihood: -1767.5623424682224
# Scatter sampling
# Sampling from dim: 1
# Epoch 11800 Train loglikelihood: -6989.270365148154
# Validation likelihood: -1761.436615739637
# Scatter sampling
# Sampling from dim: 1
# Epoch 11900 Train loglikelihood: -6965.439773571583
# Validation likelihood: -1755.3757782064417
# Scatter sampling
# Sampling from dim: 1
# Epoch 12000 Train loglikelihood: -6941.966790000958
# Validation likelihood: -1749.3365424476128
# Scatter sampling
# Sampling from dim: 1
# Epoch 12100 Train loglikelihood: -6918.866876098903
# Validation likelihood: -1743.4255161925905
# Scatter sampling
# Sampling from dim: 1
# Epoch 12200 Train loglikelihood: -6896.186865001024
# Validation likelihood: -1737.8503762368334
# Scatter sampling
# Sampling from dim: 1
# Epoch 12300 Train loglikelihood: -6874.012871350092
# Validation likelihood: -1732.5778254163233
# Scatter sampling
# Sampling from dim: 1
# Epoch 12400 Train loglikelihood: -6852.2435099150935
# Validation likelihood: -1727.4451487588817
# Scatter sampling
# Sampling from dim: 1
# Epoch 12500 Train loglikelihood: -6830.709629027313
# Validation likelihood: -1722.353232304171
# Scatter sampling
# Sampling from dim: 1
# Epoch 12600 Train loglikelihood: -6809.3947097754635
# Validation likelihood: -1717.3283379021068
# Scatter sampling
# Sampling from dim: 1
# Epoch 12700 Train loglikelihood: -6788.251522013352
# Validation likelihood: -1712.3817935439488
# Scatter sampling
# Sampling from dim: 1
# Epoch 12800 Train loglikelihood: -6767.202820524966
# Validation likelihood: -1707.547308620791
# Scatter sampling
# Sampling from dim: 1
# Epoch 12900 Train loglikelihood: -6746.333362965403
# Validation likelihood: -1702.8196885536472
# Scatter sampling
# Sampling from dim: 1
# Epoch 13000 Train loglikelihood: -6725.716875339851
# Validation likelihood: -1698.1716441383496
# Scatter sampling
# Sampling from dim: 1
# Epoch 13100 Train loglikelihood: -6705.346213790786
# Validation likelihood: -1693.6051914258262
# Scatter sampling
# Sampling from dim: 1
# Epoch 13200 Train loglikelihood: -6685.513689274656
# Validation likelihood: -1689.0715857069642
# Scatter sampling
# Sampling from dim: 1
# Epoch 13300 Train loglikelihood: -6666.32581728737
# Validation likelihood: -1684.5455250126947
# Scatter sampling
# Sampling from dim: 1
# Epoch 13400 Train loglikelihood: -6647.779831720283
# Validation likelihood: -1679.9564636360149
# Scatter sampling
# Sampling from dim: 1
# Epoch 13500 Train loglikelihood: -6629.883074646307
# Validation likelihood: -1675.0674168094743
# Scatter sampling
# Sampling from dim: 1
# Epoch 13600 Train loglikelihood: -6613.328047885656
# Validation likelihood: -1669.4117728228512
# Scatter sampling
# Sampling from dim: 1
# Epoch 13700 Train loglikelihood: -6597.00823303023
# Validation likelihood: -1664.0520950609061
# Scatter sampling
# Sampling from dim: 1
# Epoch 13800 Train loglikelihood: -6578.300080367555
# Validation likelihood: -1659.2138306523152
# Scatter sampling
# Sampling from dim: 1
# Epoch 13900 Train loglikelihood: -6560.894687908925
# Validation likelihood: -1656.1661011033439
# Scatter sampling
# Sampling from dim: 1
# Epoch 14000 Train loglikelihood: -6552.329576452174
# Validation likelihood: -1657.1790702003345
# Epoch 14100 Train loglikelihood: -6537.886885660793
# Validation likelihood: -1646.9447445654619
# Scatter sampling
# Sampling from dim: 1
# Epoch 14200 Train loglikelihood: -6525.374299209387
# Validation likelihood: -1652.240320193176
# Epoch 14300 Train loglikelihood: -6511.2143987498275
# Validation likelihood: -1638.068526903221
# Scatter sampling
# Sampling from dim: 1
# Epoch 14400 Train loglikelihood: -6475.294360126598
# Validation likelihood: -1636.0971183451898
# Scatter sampling
# Sampling from dim: 1
# Epoch 14500 Train loglikelihood: -6461.276403863604
# Validation likelihood: -1635.1361202073813
# Scatter sampling
# Sampling from dim: 1
# Epoch 14600 Train loglikelihood: -6447.771531526494
# Validation likelihood: -1632.0237334648168
# Scatter sampling
# Sampling from dim: 1
# Epoch 14700 Train loglikelihood: -6438.171666732492
# Validation likelihood: -1629.0453011844002
# Scatter sampling
# Sampling from dim: 1
# Epoch 14800 Train loglikelihood: -6425.123030671091
# Validation likelihood: -1626.6207171396447
# Scatter sampling
# Sampling from dim: 1
# Epoch 14900 Train loglikelihood: -6410.433154655824
# Validation likelihood: -1624.083705286853
# Scatter sampling
# Sampling from dim: 1
# Epoch 15000 Train loglikelihood: -6394.970005475171
# Validation likelihood: -1620.5997080480815
# Scatter sampling
# Sampling from dim: 1
# Epoch 15100 Train loglikelihood: -6378.5324448366555
# Validation likelihood: -1617.0370745133591
# Scatter sampling
# Sampling from dim: 1
# Epoch 15200 Train loglikelihood: -6363.425260362729
# Validation likelihood: -1613.8424107775463
# Scatter sampling
# Sampling from dim: 1
# Epoch 15300 Train loglikelihood: -6347.05341329246
# Validation likelihood: -1609.6368022042989
# Scatter sampling
# Sampling from dim: 1
# Epoch 15400 Train loglikelihood: -6332.022276596532
# Validation likelihood: -1607.3147513371664
# Scatter sampling
# Sampling from dim: 1
# Epoch 15500 Train loglikelihood: -6318.207451950697
# Validation likelihood: -1603.34447486302
# Scatter sampling
# Sampling from dim: 1
# Epoch 15600 Train loglikelihood: -6295.928806649386
# Validation likelihood: -1598.1919600938336
# Scatter sampling
# Sampling from dim: 1
# Epoch 15700 Train loglikelihood: -6287.916293267742
# Validation likelihood: -1598.1068772570015
# Scatter sampling
# Sampling from dim: 1
# Epoch 15800 Train loglikelihood: -6268.359141899557
# Validation likelihood: -1590.8253522362718
# Scatter sampling
# Sampling from dim: 1
# Epoch 15900 Train loglikelihood: -6242.216526160965
# Validation likelihood: -1587.0394987790778
# Scatter sampling
# Sampling from dim: 1
# Epoch 16000 Train loglikelihood: -6243.433035741
# Validation likelihood: -1586.3745545365923
# Scatter sampling
# Sampling from dim: 1
# Epoch 16100 Train loglikelihood: -6219.483378507766
# Validation likelihood: -1581.4524787469136
# Scatter sampling
# Sampling from dim: 1
# Epoch 16200 Train loglikelihood: -6215.034775126721
# Validation likelihood: -1582.8625156097964
# Epoch 16300 Train loglikelihood: -6185.179737595544
# Validation likelihood: -1568.2281985934296
# Scatter sampling
# Sampling from dim: 1
# Epoch 16400 Train loglikelihood: -6183.021106697741
# Validation likelihood: -1573.2744467329233
# Epoch 16500 Train loglikelihood: -6155.312870368049
# Validation likelihood: -1561.4924201805065
# Scatter sampling
# Sampling from dim: 1
# Epoch 16600 Train loglikelihood: -6163.813587681921
# Validation likelihood: -1571.3447851039045
# Epoch 16700 Train loglikelihood: -6168.380785930253
# Validation likelihood: -1559.3662898685438
# Scatter sampling
# Sampling from dim: 1
# Epoch 16800 Train loglikelihood: -6133.351036437647
# Validation likelihood: -1569.7790873968108
# Epoch 16900 Train loglikelihood: -6108.200301809358
# Validation likelihood: -1552.0828698255855
# Scatter sampling
# Sampling from dim: 1
# Epoch 17000 Train loglikelihood: -6110.257733885974
# Validation likelihood: -1558.7937640205269
# Epoch 17100 Train loglikelihood: -6074.535599642154
# Validation likelihood: -1556.470143038311
# Epoch 17200 Train loglikelihood: -6048.466593171206
# Validation likelihood: -1540.6097716601982
# Scatter sampling
# Sampling from dim: 1
# Epoch 17300 Train loglikelihood: -6060.71983048887
# Validation likelihood: -1542.870279741841
# Epoch 17400 Train loglikelihood: -6042.170254780185
# Validation likelihood: -1538.5996614306941
# Scatter sampling
# Sampling from dim: 1
# Epoch 17500 Train loglikelihood: -6030.424623619785
# Validation likelihood: -1535.5517723643943
# Scatter sampling
# Sampling from dim: 1
# Epoch 17600 Train loglikelihood: -6050.761632420749
# Validation likelihood: -1552.145817732491
# Epoch 17700 Train loglikelihood: -6018.2691252665845
# Validation likelihood: -1526.1922362095404
# Scatter sampling
# Sampling from dim: 1
# Epoch 17800 Train loglikelihood: -5995.064681949515
# Validation likelihood: -1534.9773679353912
# Epoch 17900 Train loglikelihood: -5972.399685533724
# Validation likelihood: -1520.6374017604587
# Scatter sampling
# Sampling from dim: 1
# Epoch 18000 Train loglikelihood: -5964.070557304537
# Validation likelihood: -1545.4804682001904
# Epoch 18100 Train loglikelihood: -5937.66581731756
# Validation likelihood: -1513.0748911789165
# Scatter sampling
# Sampling from dim: 1
# Epoch 18200 Train loglikelihood: -6432.913937708889
# Validation likelihood: -1538.0155941455255
# Epoch 18300 Train loglikelihood: -6068.977692172344
# Validation likelihood: -1509.5526955253126
# Scatter sampling
# Sampling from dim: 1
# Epoch 18400 Train loglikelihood: -5899.433123263325
# Validation likelihood: -1522.5936615388396
# Epoch 18500 Train loglikelihood: -5892.651371895372
# Validation likelihood: -1501.5597898164206
# Scatter sampling
# Sampling from dim: 1
# Epoch 18600 Train loglikelihood: -5868.911908710082
# Validation likelihood: -1509.2331811733152
# Epoch 18700 Train loglikelihood: -5874.56624773062
# Validation likelihood: -1501.9085896835095
# Epoch 18800 Train loglikelihood: -5844.146967837627
# Validation likelihood: -1496.9930552061126
# Scatter sampling
# Sampling from dim: 1
# Epoch 18900 Train loglikelihood: -5871.166933121851
# Validation likelihood: -1527.8524034664492
# Epoch 19000 Train loglikelihood: -5837.595628826175
# Validation likelihood: -1489.148638322657
# Scatter sampling
# Sampling from dim: 1
# Epoch 19100 Train loglikelihood: -5825.438857842183
# Validation likelihood: -1503.4285836284093
# Epoch 19200 Train loglikelihood: -5809.068409673899
# Validation likelihood: -1482.839570999586
# Scatter sampling
# Sampling from dim: 1
# Epoch 19300 Train loglikelihood: -5785.868990430696
# Validation likelihood: -1493.6294062832894
# Epoch 19400 Train loglikelihood: -5785.537910959621
# Validation likelihood: -1478.0529940617616
# Scatter sampling
# Sampling from dim: 1
# Epoch 19500 Train loglikelihood: -5765.826188384635
# Validation likelihood: -1481.2466118514653
# Epoch 19600 Train loglikelihood: -5785.501822760294
# Validation likelihood: -1514.1522288967826
# Epoch 19700 Train loglikelihood: -5741.078374629248
# Validation likelihood: -1470.1588290992404
# Scatter sampling
# Sampling from dim: 1
# Epoch 19800 Train loglikelihood: -5742.46839337046
# Validation likelihood: -1475.3827539727515
# Epoch 19900 Train loglikelihood: -5757.584667597339
# Validation likelihood: -1465.7508630118937
# Scatter sampling
# Sampling from dim: 1
# Epoch 20000 Train loglikelihood: -5710.917402197347
# Validation likelihood: -1466.9815890743216
# Epoch 20100 Train loglikelihood: -5735.3074353266875
# Validation likelihood: -1497.3142817666592
# Epoch 20200 Train loglikelihood: -5683.55298516113
# Validation likelihood: -1459.2866480944872
# Scatter sampling
# Sampling from dim: 1
# Epoch 20300 Train loglikelihood: -5720.629449559252
# Validation likelihood: -1463.5853825148197
# Epoch 20400 Train loglikelihood: -5682.3404154380805
# Validation likelihood: -1452.2261870655148
# Scatter sampling
# Sampling from dim: 1
# Epoch 20500 Train loglikelihood: -5748.515376096658
# Validation likelihood: -1460.448530922662
# Epoch 20600 Train loglikelihood: -5659.734558512901
# Validation likelihood: -1450.6166476348117
# Scatter sampling
# Sampling from dim: 1
# Epoch 20700 Train loglikelihood: -5631.654847621658
# Validation likelihood: -1449.9891958038643
# Scatter sampling
# Sampling from dim: 1
# Epoch 20800 Train loglikelihood: -5626.2466186751535
# Validation likelihood: -1447.9237351236552
# Scatter sampling
# Sampling from dim: 1
# Epoch 20900 Train loglikelihood: -5632.238538459782
# Validation likelihood: -1442.4473114637622
# Scatter sampling
# Sampling from dim: 1
# Epoch 21000 Train loglikelihood: -5600.06803244781
# Validation likelihood: -1443.8913820720559
# Epoch 21100 Train loglikelihood: -5634.978253199135
# Validation likelihood: -1460.204396615381
# Epoch 21200 Train loglikelihood: -5574.278102438676
# Validation likelihood: -1435.7070228705797
# Scatter sampling
# Sampling from dim: 1
# Epoch 21300 Train loglikelihood: -5569.412305756605
# Validation likelihood: -1434.8817374672306
# Scatter sampling
# Sampling from dim: 1
# Epoch 21400 Train loglikelihood: -5635.505147154223
# Validation likelihood: -1442.9481004780464
# Epoch 21500 Train loglikelihood: -5570.407407850575
# Validation likelihood: -1429.0558346003381
# Scatter sampling
# Sampling from dim: 1
# Epoch 21600 Train loglikelihood: -5541.529786035937
# Validation likelihood: -1428.6601277669886
# Scatter sampling
# Sampling from dim: 1
# Epoch 21700 Train loglikelihood: -5566.282754325022
# Validation likelihood: -1436.4402558431898
# Epoch 21800 Train loglikelihood: -5584.556764994609
# Validation likelihood: -1420.7113892646212
# Scatter sampling
# Sampling from dim: 1
# Epoch 21900 Train loglikelihood: -5509.540487793833
# Validation likelihood: -1433.9355228732825
# Epoch 22000 Train loglikelihood: -5505.775720274235
# Validation likelihood: -1413.8843152465838
# Scatter sampling
# Sampling from dim: 1
# Epoch 22100 Train loglikelihood: -5502.524712563694
# Validation likelihood: -1417.2096783736674
# Epoch 22200 Train loglikelihood: -5572.033639802393
# Validation likelihood: -1449.3700765599547
# Epoch 22300 Train loglikelihood: -5458.36065659366
# Validation likelihood: -1410.576021810607
# Scatter sampling
# Sampling from dim: 1
# Epoch 22400 Train loglikelihood: -5467.693370163752
# Validation likelihood: -1449.6693165649085
# Epoch 22500 Train loglikelihood: -5504.984316456458
# Validation likelihood: -1419.8008194290956
# Epoch 22600 Train loglikelihood: -5432.496994749849
# Validation likelihood: -1405.2567187378386
# Scatter sampling
# Sampling from dim: 1
# Epoch 22700 Train loglikelihood: -5426.002091033119
# Validation likelihood: -1407.187672104769
# Epoch 22800 Train loglikelihood: -5469.7665486836295
# Validation likelihood: -1397.456206778379
# Scatter sampling
# Sampling from dim: 1
# Epoch 22900 Train loglikelihood: -5436.802230980109
# Validation likelihood: -1425.3698701611663
# Epoch 23000 Train loglikelihood: -5408.501998444351
# Validation likelihood: -1391.6825357697467
# Scatter sampling
# Sampling from dim: 1
# Epoch 23100 Train loglikelihood: -5385.512155183591
# Validation likelihood: -1428.5511686326843
# Epoch 23200 Train loglikelihood: -5385.060892531696
# Validation likelihood: -1408.5342870581546
# Epoch 23300 Train loglikelihood: -5514.349936681889
# Validation likelihood: -1394.9181607290068
# Epoch 23400 Train loglikelihood: -5350.024640767658
# Validation likelihood: -1383.8610258072313
# Scatter sampling
# Sampling from dim: 1
# Epoch 23500 Train loglikelihood: -5446.030229123047
# Validation likelihood: -1387.8958541483894
# Epoch 23600 Train loglikelihood: -5359.4604983838835
# Validation likelihood: -1383.5342112518526
# Scatter sampling
# Sampling from dim: 1
# Epoch 23700 Train loglikelihood: -5334.6709045113475
# Validation likelihood: -1387.4247007411827
# Epoch 23800 Train loglikelihood: -5597.658375630078
# Validation likelihood: -1390.9085260740499
# Epoch 23900 Train loglikelihood: -5397.536866087549
# Validation likelihood: -1379.4313709141875
# Scatter sampling
# Sampling from dim: 1
# Epoch 24000 Train loglikelihood: -5315.108118959301
# Validation likelihood: -1380.6685329918535
# Epoch 24100 Train loglikelihood: -5376.443059099172
# Validation likelihood: -1420.2732417243465
# Epoch 24200 Train loglikelihood: -5297.2526877820965
# Validation likelihood: -1372.4900580106723
# Scatter sampling
# Sampling from dim: 1
# Epoch 24300 Train loglikelihood: -5639.7352302146965
# Validation likelihood: -1419.0714105580205
# Epoch 24400 Train loglikelihood: -5265.61759215504
# Validation likelihood: -1362.0688393910436
# Scatter sampling
# Sampling from dim: 1
# Epoch 24500 Train loglikelihood: -5296.436033375874
# Validation likelihood: -1371.050931806114
# Epoch 24600 Train loglikelihood: -5384.4259197635165
# Validation likelihood: -1360.8947984415408
# Scatter sampling
# Sampling from dim: 1
# Epoch 24700 Train loglikelihood: -5270.617570316648
# Validation likelihood: -1382.5991909457375
# Epoch 24800 Train loglikelihood: -5303.436944715479
# Validation likelihood: -1359.6087537346843
# Scatter sampling
# Sampling from dim: 1
# Epoch 24900 Train loglikelihood: -5232.520628790837
# Validation likelihood: -1361.4397622618367
# Epoch 25000 Train loglikelihood: -5219.276003453064
# Validation likelihood: -1382.113284500519
# Epoch 25100 Train loglikelihood: -5208.009486970423
# Validation likelihood: -1354.7187055835007
# Scatter sampling
# Sampling from dim: 1
# Epoch 25200 Train loglikelihood: -5197.5006039674245
# Validation likelihood: -1371.9831963345068
# Epoch 25300 Train loglikelihood: -5198.283217378698
# Validation likelihood: -1345.5957031168814
# Scatter sampling
# Sampling from dim: 1
# Epoch 25400 Train loglikelihood: -5352.063012246705
# Validation likelihood: -1388.8110160404774
# Epoch 25500 Train loglikelihood: -5206.105930499625
# Validation likelihood: -1344.8536022364324
# Scatter sampling
# Sampling from dim: 1
# Epoch 25600 Train loglikelihood: -5176.14868532428
# Validation likelihood: -1349.1858218529824
# Epoch 25700 Train loglikelihood: -5150.132108006479
# Validation likelihood: -1339.3071721051854
# Scatter sampling
# Sampling from dim: 1
# Epoch 25800 Train loglikelihood: -5283.117512613632
# Validation likelihood: -1381.2066198595992
# Epoch 25900 Train loglikelihood: -5142.763465304719
# Validation likelihood: -1339.1585373763282
# Scatter sampling
# Sampling from dim: 1
# Epoch 26000 Train loglikelihood: -5139.747189853524
# Validation likelihood: -1340.3580290672714
# Epoch 26100 Train loglikelihood: -5128.754012234142
# Validation likelihood: -1351.157645297174
# Epoch 26200 Train loglikelihood: -5238.694142294025
# Validation likelihood: -1335.2424391797053
# Scatter sampling
# Sampling from dim: 1
# Epoch 26300 Train loglikelihood: -5115.4121939668785
# Validation likelihood: -1334.1731488813075
# Scatter sampling
# Sampling from dim: 1
# Epoch 26400 Train loglikelihood: -5134.14008153922
# Validation likelihood: -1347.2520366680742
# Epoch 26500 Train loglikelihood: -5146.56924621474
# Validation likelihood: -1351.6441318840148
# Epoch 26600 Train loglikelihood: -5184.473031635123
# Validation likelihood: -1326.4440341542695
# Scatter sampling
# Sampling from dim: 1
# Epoch 26700 Train loglikelihood: -5092.343962335271
# Validation likelihood: -1326.708054157239
# Epoch 26800 Train loglikelihood: -5051.567886815842
# Validation likelihood: -1317.9397216934274
# Scatter sampling
# Sampling from dim: 1
# Epoch 26900 Train loglikelihood: -5075.51489935418
# Validation likelihood: -1324.2790638302367
# Epoch 27000 Train loglikelihood: -5042.009649425684
# Validation likelihood: -1313.19277647078
# Scatter sampling
# Sampling from dim: 1
# Epoch 27100 Train loglikelihood: -5071.032168402557
# Validation likelihood: -1372.1718030425197
# Epoch 27200 Train loglikelihood: -5080.395816431166
# Validation likelihood: -1314.9298019690584
# Epoch 27300 Train loglikelihood: -5036.470554328509
# Validation likelihood: -1313.7227348353447
# Epoch 27400 Train loglikelihood: -4992.4449469239335
# Validation likelihood: -1307.4468013651372
# Scatter sampling
# Sampling from dim: 1
# Epoch 27500 Train loglikelihood: -5049.404492200654
# Validation likelihood: -1324.0128184214939
# Epoch 27600 Train loglikelihood: -5054.216876358772
# Validation likelihood: -1301.968377638512
# Scatter sampling
# Sampling from dim: 1
# Epoch 27700 Train loglikelihood: -4995.0822441848995
# Validation likelihood: -1310.6578447441025
# Epoch 27800 Train loglikelihood: -5015.035486940388
# Validation likelihood: -1300.4338305148806
# Scatter sampling
# Sampling from dim: 1
# Epoch 27900 Train loglikelihood: -5135.187225192569
# Validation likelihood: -1332.3892020625888
# Epoch 28000 Train loglikelihood: -4964.172468102452
# Validation likelihood: -1294.8148335128967
# Scatter sampling
# Sampling from dim: 1
# Epoch 28100 Train loglikelihood: -5033.3034453752225
# Validation likelihood: -1329.3464178156705
# Epoch 28200 Train loglikelihood: -4976.663185133499
# Validation likelihood: -1294.897348777525
# Epoch 28300 Train loglikelihood: -5159.079752839492
# Validation likelihood: -1358.1201177071548
# Epoch 28400 Train loglikelihood: -4933.434561709139
# Validation likelihood: -1320.1625208793512
# Epoch 28500 Train loglikelihood: -4947.095169038204
# Validation likelihood: -1291.050315236001
# Scatter sampling
# Sampling from dim: 1
# Epoch 28600 Train loglikelihood: -4927.747993025087
# Validation likelihood: -1297.946581432233
# Epoch 28700 Train loglikelihood: -5098.4972328408485
# Validation likelihood: -1329.7030644067956
# Epoch 28800 Train loglikelihood: -5049.124363598715
# Validation likelihood: -1289.1963846328779
# Scatter sampling
# Sampling from dim: 1
# Epoch 28900 Train loglikelihood: -4899.2809754533555
# Validation likelihood: -1289.4972965133566
# Epoch 29000 Train loglikelihood: -5047.419903104784
# Validation likelihood: -1296.9167023717173
# Epoch 29100 Train loglikelihood: -4986.683758058119
# Validation likelihood: -1284.2331869803972
# Scatter sampling
# Sampling from dim: 1
# Epoch 29200 Train loglikelihood: -5085.790337834907
# Validation likelihood: -1333.0090562385014
# Epoch 29300 Train loglikelihood: -5077.73587653108
# Validation likelihood: -1270.557440092127
# Scatter sampling
# Sampling from dim: 1
# Epoch 29400 Train loglikelihood: -4880.199671005182
# Validation likelihood: -1277.7268404178071
# Epoch 29500 Train loglikelihood: -4847.407900596301
# Validation likelihood: -1266.500167929356
# Scatter sampling
# Sampling from dim: 1
# Epoch 29600 Train loglikelihood: -4849.292846689166
# Validation likelihood: -1306.857389614594
# Epoch 29700 Train loglikelihood: -4816.004700420512
# Validation likelihood: -1264.517975745352
# Scatter sampling
# Sampling from dim: 1
# Epoch 29800 Train loglikelihood: -4857.118812462168
# Validation likelihood: -1270.0884657134416
# Epoch 29900 Train loglikelihood: -4896.909202917929
# Validation likelihood: -1269.006587660284
# Epoch 30000 Train loglikelihood: -4811.481087991233
# Validation likelihood: -1314.1660477612413
# Epoch 30100 Train loglikelihood: -4798.64937496395
# Validation likelihood: -1264.231685643272
# Scatter sampling
# Sampling from dim: 1
# Epoch 30200 Train loglikelihood: -4966.349952343547
# Validation likelihood: -1328.1258579244166
# Epoch 30300 Train loglikelihood: -4793.906501961323
# Validation likelihood: -1256.907677000589
# Scatter sampling
# Sampling from dim: 1
# Epoch 30400 Train loglikelihood: -4780.410154414868
# Validation likelihood: -1270.4498142039242
# Epoch 30500 Train loglikelihood: -4747.247726529193
# Validation likelihood: -1247.3336147925324
# Scatter sampling
# Sampling from dim: 1
# Epoch 30600 Train loglikelihood: -4801.3822381449445
# Validation likelihood: -1338.5491623230503
# Epoch 30700 Train loglikelihood: -4771.260698630594
# Validation likelihood: -1262.5522590979567
# Epoch 30800 Train loglikelihood: -4856.858348959781
# Validation likelihood: -1255.7023468910756
# Epoch 30900 Train loglikelihood: -4707.926032390367
# Validation likelihood: -1276.5882483404175
# Epoch 31000 Train loglikelihood: -4824.031022098507
# Validation likelihood: -1269.6569054973288
# Epoch 31100 Train loglikelihood: -4741.381048442086
# Validation likelihood: -1270.0611986156327
# Epoch 31200 Train loglikelihood: -4765.9343716136755
# Validation likelihood: -1253.378484124962
# Epoch 31300 Train loglikelihood: -4921.321595752898
# Validation likelihood: -1262.1410839878731
# Epoch 31400 Train loglikelihood: -4803.053152335401
# Validation likelihood: -1245.95907293917
# Scatter sampling
# Sampling from dim: 1
# Epoch 31500 Train loglikelihood: -4743.601613380572
# Validation likelihood: -1292.4662603209936
# Epoch 31600 Train loglikelihood: -4737.9648490365435
# Validation likelihood: -1239.4548256554672
# Scatter sampling
# Sampling from dim: 1
# Epoch 31700 Train loglikelihood: -4752.64948394422
# Validation likelihood: -1293.0679366890536
# Epoch 31800 Train loglikelihood: -4786.842835805374
# Validation likelihood: -1241.1698027287166
# Epoch 31900 Train loglikelihood: -4691.474228252654
# Validation likelihood: -1235.5948325025856
# Scatter sampling
# Sampling from dim: 1
# Epoch 32000 Train loglikelihood: -4669.968103986603
# Validation likelihood: -1230.7293126251172
# Scatter sampling
# Sampling from dim: 1
# Epoch 32100 Train loglikelihood: -4733.180039262035
# Validation likelihood: -1245.2067378167437
# Epoch 32200 Train loglikelihood: -4620.13113103746
# Validation likelihood: -1219.848464516821
# Scatter sampling
# Sampling from dim: 1
# Epoch 32300 Train loglikelihood: -4652.820806978558
# Validation likelihood: -1252.3443791963846
# Epoch 32400 Train loglikelihood: -4652.083441792092
# Validation likelihood: -1236.847228441957
# Epoch 32500 Train loglikelihood: -4621.095989960031
# Validation likelihood: -1267.2446413683888
# Epoch 32600 Train loglikelihood: -4594.999482062802
# Validation likelihood: -1235.8913674394723
# Epoch 32700 Train loglikelihood: -4597.051306046073
# Validation likelihood: -1256.266571632545
# Epoch 32800 Train loglikelihood: -4572.796869061215
# Validation likelihood: -1215.5069056703614
# Scatter sampling
# Sampling from dim: 1
# Epoch 32900 Train loglikelihood: -4645.666772573151
# Validation likelihood: -1308.4151204304808
# Epoch 33000 Train loglikelihood: -4894.913267735905
# Validation likelihood: -1231.463469914593
# Epoch 33100 Train loglikelihood: -4557.443504555398
# Validation likelihood: -1208.1218882587186
# Scatter sampling
# Sampling from dim: 1
# Epoch 33200 Train loglikelihood: -4565.526448239275
# Validation likelihood: -1205.602528260959
# Scatter sampling
# Sampling from dim: 1
# Epoch 33300 Train loglikelihood: -4578.940553823732
# Validation likelihood: -1257.0619610717695
# Epoch 33400 Train loglikelihood: -4568.121091142386
# Validation likelihood: -1203.1031387609266
# Scatter sampling
# Sampling from dim: 1
# Epoch 33500 Train loglikelihood: -4536.291362712459
# Validation likelihood: -1200.223955351838
# Scatter sampling
# Sampling from dim: 1
# Epoch 33600 Train loglikelihood: -4561.494787968097
# Validation likelihood: -1199.9857605205063
# Scatter sampling
# Sampling from dim: 1
# Epoch 33700 Train loglikelihood: -4615.488653480505
# Validation likelihood: -1210.7626281158832
# Epoch 33800 Train loglikelihood: -4510.98639458901
# Validation likelihood: -1196.3363768765137
# Scatter sampling
# Sampling from dim: 1
# Epoch 33900 Train loglikelihood: -4638.485614877848
# Validation likelihood: -1200.3303432285272
# Epoch 34000 Train loglikelihood: -4460.47800586685
# Validation likelihood: -1187.1918117897708
# Scatter sampling
# Sampling from dim: 1
# Epoch 34100 Train loglikelihood: -4490.2560351951015
# Validation likelihood: -1260.1835668184601
# Epoch 34200 Train loglikelihood: -4759.2321421302295
# Validation likelihood: -1180.5903258306473
# Scatter sampling
# Sampling from dim: 1
# Epoch 34300 Train loglikelihood: -4614.557459118112
# Validation likelihood: -1191.094481544498
# Epoch 34400 Train loglikelihood: -4427.748603042058
# Validation likelihood: -1173.639127147378
# Scatter sampling
# Sampling from dim: 1
# Epoch 34500 Train loglikelihood: -4523.3900540056975
# Validation likelihood: -1200.253430716505
# Epoch 34600 Train loglikelihood: -4424.781550755364
# Validation likelihood: -1183.6811671296855
# Epoch 34700 Train loglikelihood: -4546.052682963103
# Validation likelihood: -1219.380765626127
# Epoch 34800 Train loglikelihood: -4450.566820269742
# Validation likelihood: -1246.9937534792107
# Epoch 34900 Train loglikelihood: -4534.45374485566
# Validation likelihood: -1219.0752277836557
# Epoch 35000 Train loglikelihood: -4374.529671761851
# Validation likelihood: -1174.9830099215005
# Epoch 35100 Train loglikelihood: -4572.667173070477
# Validation likelihood: -1244.4652861358495
# Epoch 35200 Train loglikelihood: -4375.734926996549
# Validation likelihood: -1165.2496667744936
# Scatter sampling
# Sampling from dim: 1
# Epoch 35300 Train loglikelihood: -4533.510499986036
# Validation likelihood: -1191.6845894002681
# Epoch 35400 Train loglikelihood: -4333.57087647714
# Validation likelihood: -1153.3881021581428
# Scatter sampling
# Sampling from dim: 1
# Epoch 35500 Train loglikelihood: -4625.798959729257
# Validation likelihood: -1187.7334487529106
# Epoch 35600 Train loglikelihood: -4758.237143070156
# Validation likelihood: -1197.5712711981027
# Epoch 35700 Train loglikelihood: -4354.782134658323
# Validation likelihood: -1156.9662702229748
# Epoch 35800 Train loglikelihood: -4355.2146316907665
# Validation likelihood: -1170.6363753172295
# Epoch 35900 Train loglikelihood: -4409.735552696544
# Validation likelihood: -1166.6633845954152
# Epoch 36000 Train loglikelihood: -4332.097612510324
# Validation likelihood: -1151.7954099255446
# Scatter sampling
# Sampling from dim: 1
# Epoch 36100 Train loglikelihood: -4365.592176000555
# Validation likelihood: -1165.321098666103
# Epoch 36200 Train loglikelihood: -4554.442534477619
# Validation likelihood: -1239.4711613817303
# Epoch 36300 Train loglikelihood: -4285.375496539078
# Validation likelihood: -1148.5934962504543
# Scatter sampling
# Sampling from dim: 1
# Epoch 36400 Train loglikelihood: -4322.8334303647725
# Validation likelihood: -1147.246781562413
# Scatter sampling
# Sampling from dim: 1
# Epoch 36500 Train loglikelihood: -4304.728931458663
# Validation likelihood: -1145.8018305872145
# Scatter sampling
# Sampling from dim: 1
# Epoch 36600 Train loglikelihood: -4584.210847217167
# Validation likelihood: -1140.516159376989
# Scatter sampling
# Sampling from dim: 1
# Epoch 36700 Train loglikelihood: -4285.536875165057
# Validation likelihood: -1158.8117533388763
# Epoch 36800 Train loglikelihood: -4327.014905018713
# Validation likelihood: -1174.2542589731322
# Epoch 36900 Train loglikelihood: -4489.174233128395
# Validation likelihood: -1229.0824423051645
# Epoch 37000 Train loglikelihood: -4188.260406415625
# Validation likelihood: -1131.367926414795
# Scatter sampling
# Sampling from dim: 1
# Epoch 37100 Train loglikelihood: -4478.904297059325
# Validation likelihood: -1153.8191471986029
# Epoch 37200 Train loglikelihood: -4195.99599351391
# Validation likelihood: -1125.6041078687558
# Scatter sampling
# Sampling from dim: 1
# Epoch 37300 Train loglikelihood: -4193.693386941769
# Validation likelihood: -1138.7703910892583
# Epoch 37400 Train loglikelihood: -4261.020711269619
# Validation likelihood: -1131.9537576327657
# Epoch 37500 Train loglikelihood: -4177.627443070389
# Validation likelihood: -1122.691075915359
# Scatter sampling
# Sampling from dim: 1
# Epoch 37600 Train loglikelihood: -4224.936269987554
# Validation likelihood: -1219.2332258806957
# Epoch 37700 Train loglikelihood: -4220.7188028814735
# Validation likelihood: -1124.1246832687839
# Epoch 37800 Train loglikelihood: -4229.451757143896
# Validation likelihood: -1144.9032876487126
# Epoch 37900 Train loglikelihood: -4138.027721339442
# Validation likelihood: -1115.7515420878058
# Scatter sampling
# Sampling from dim: 1
# Epoch 38000 Train loglikelihood: -4167.410161692259
# Validation likelihood: -1116.2629860227607
# Epoch 38100 Train loglikelihood: -4614.352681036604
# Validation likelihood: -1142.925170953176
# Epoch 38200 Train loglikelihood: -4232.760364127576
# Validation likelihood: -1133.5307269747118
# Epoch 38300 Train loglikelihood: -4076.494955727171
# Validation likelihood: -1127.7894155529668
# Epoch 38400 Train loglikelihood: -4228.842934224649
# Validation likelihood: -1120.1137672824718
# Epoch 38500 Train loglikelihood: -4092.476190918898
# Validation likelihood: -1131.0847123900337
# Epoch 38600 Train loglikelihood: -4144.717084267653
# Validation likelihood: -1151.5144333182075
# Epoch 38700 Train loglikelihood: -4149.6964323718385
# Validation likelihood: -1155.186171477179
# Epoch 38800 Train loglikelihood: -4152.6019358396
# Validation likelihood: -1162.7674726906216
# Epoch 38900 Train loglikelihood: -4110.547828644287
# Validation likelihood: -1092.6635953155394
# Scatter sampling
# Sampling from dim: 1
# Epoch 39000 Train loglikelihood: -4179.288968919027
# Validation likelihood: -1231.8171296944242
# Epoch 39100 Train loglikelihood: -4031.3648160704925
# Validation likelihood: -1097.1747818577726
# Epoch 39200 Train loglikelihood: -4139.450853046828
# Validation likelihood: -1105.0740978125134
# Epoch 39300 Train loglikelihood: -4772.975852886344
# Validation likelihood: -1160.5666727396938
# Epoch 39400 Train loglikelihood: -4188.484376748345
# Validation likelihood: -1129.768271154092
# Epoch 39500 Train loglikelihood: -3980.161436427026
# Validation likelihood: -1100.4228938821939
# Epoch 39600 Train loglikelihood: -4206.172039699281
# Validation likelihood: -1158.0707829195671
# Epoch 39700 Train loglikelihood: -4612.521811462203
# Validation likelihood: -1279.285050505941
# Epoch 39800 Train loglikelihood: -3999.7774086052455
# Validation likelihood: -1141.2492686267142
# Epoch 39900 Train loglikelihood: -4036.9563123462462
# Validation likelihood: -1080.6771347172407
# Scatter sampling
# Sampling from dim: 1
# Epoch 40000 Train loglikelihood: -4064.2061908844653
# Validation likelihood: -1104.005018633142
# Epoch 40100 Train loglikelihood: -3946.017921865399
# Validation likelihood: -1082.1244510310794
# Epoch 40200 Train loglikelihood: -4014.8109481425126
# Validation likelihood: -1083.9006776022293
# Epoch 40300 Train loglikelihood: -4387.953614332938
# Validation likelihood: -1111.8435407148108
# Epoch 40400 Train loglikelihood: -4115.905925321554
# Validation likelihood: -1119.8342300413478
# Epoch 40500 Train loglikelihood: -3980.5417304077246
# Validation likelihood: -1084.0888470799646
# Epoch 40600 Train loglikelihood: -4004.7247494710955
# Validation likelihood: -1104.062317799509
# Epoch 40700 Train loglikelihood: -3968.810355514034
# Validation likelihood: -1096.1425915048194
# Epoch 40800 Train loglikelihood: -3891.969217509355
# Validation likelihood: -1087.7178417398197
# Epoch 40900 Train loglikelihood: -4069.2974638177025
# Validation likelihood: -1081.6416504827396
# Epoch 41000 Train loglikelihood: -3939.956844188685
# Validation likelihood: -1091.739794225845
# Epoch 41100 Train loglikelihood: -3957.668988454797
# Validation likelihood: -1078.0559772711647
# Scatter sampling
# Sampling from dim: 1
# Epoch 41200 Train loglikelihood: -3934.117798597793
# Validation likelihood: -1071.3786424667405
# Scatter sampling
# Sampling from dim: 1
# Epoch 41300 Train loglikelihood: -4042.506218812433
# Validation likelihood: -1095.7561102150894
# Epoch 41400 Train loglikelihood: -4000.217227218093
# Validation likelihood: -1074.223685812699
# Epoch 41500 Train loglikelihood: -3906.6413408283925
# Validation likelihood: -1069.2247796759264
# Scatter sampling
# Sampling from dim: 1
# Epoch 41600 Train loglikelihood: -3875.601519657881
# Validation likelihood: -1101.4043084501955
# Epoch 41700 Train loglikelihood: -3823.431602750524
# Validation likelihood: -1058.445688955469
# Scatter sampling
# Sampling from dim: 1
# Epoch 41800 Train loglikelihood: -3839.5650200623295
# Validation likelihood: -1081.3654105526134
# Epoch 41900 Train loglikelihood: -3782.371266234387
# Validation likelihood: -1049.8580957245902
# Scatter sampling
# Sampling from dim: 1
# Epoch 42000 Train loglikelihood: -3861.660970454972
# Validation likelihood: -1056.5259021358215
# Epoch 42100 Train loglikelihood: -3935.571895656461
# Validation likelihood: -1060.415108807214
# Epoch 42200 Train loglikelihood: -3802.3480685584436
# Validation likelihood: -1047.7536018641267
# Scatter sampling
# Sampling from dim: 1
# Epoch 42300 Train loglikelihood: -4006.4507151645525
# Validation likelihood: -1073.6303062936024
# Epoch 42400 Train loglikelihood: -3747.7602972880964
# Validation likelihood: -1041.544762898033
# Scatter sampling
# Sampling from dim: 1
# Epoch 42500 Train loglikelihood: -3885.0193539730444
# Validation likelihood: -1076.6876978659845
# Epoch 42600 Train loglikelihood: -3804.0523724424866
# Validation likelihood: -1067.446935749248
# Epoch 42700 Train loglikelihood: -3790.7350529753357
# Validation likelihood: -1077.4427265459228
# Epoch 42800 Train loglikelihood: -3758.020444730573
# Validation likelihood: -1094.663077545937
# Epoch 42900 Train loglikelihood: -3876.3982251055177
# Validation likelihood: -1052.239336956571
# Epoch 43000 Train loglikelihood: -3971.105043667745
# Validation likelihood: -1114.6559950799729
# Epoch 43100 Train loglikelihood: -3837.8716044201356
# Validation likelihood: -1070.1604271380056
# Epoch 43200 Train loglikelihood: -3996.267620737533
# Validation likelihood: -1046.1098514568152
# Epoch 43300 Train loglikelihood: -3754.5246014684126
# Validation likelihood: -1034.046708697836
# Scatter sampling
# Sampling from dim: 1
# Epoch 43400 Train loglikelihood: -3776.8746401891212
# Validation likelihood: -1034.5684813147022
# Epoch 43500 Train loglikelihood: -3720.6299811868184
# Validation likelihood: -1027.0145498495467
# Scatter sampling
# Sampling from dim: 1
# Epoch 43600 Train loglikelihood: -3752.579851105434
# Validation likelihood: -1033.194265865717
# Epoch 43700 Train loglikelihood: -3704.1533693172
# Validation likelihood: -1033.8514272141783
# Epoch 43800 Train loglikelihood: -3670.479524618264
# Validation likelihood: -1036.0266648619684
# Epoch 43900 Train loglikelihood: -3970.09910852732
# Validation likelihood: -1075.6540820001946
# Epoch 44000 Train loglikelihood: -3947.8981181612303
# Validation likelihood: -1106.6949050919948
# Epoch 44100 Train loglikelihood: -3712.5112406141234
# Validation likelihood: -1027.041618587647
# Epoch 44200 Train loglikelihood: -3720.3245476385882
# Validation likelihood: -1029.6006120616635
# Epoch 44300 Train loglikelihood: -3678.461405915426
# Validation likelihood: -1005.6638897496862
# Scatter sampling
# Sampling from dim: 1
# Epoch 44400 Train loglikelihood: -4011.2348079163285
# Validation likelihood: -1026.8028452270137
# Epoch 44500 Train loglikelihood: -4009.1295634009102
# Validation likelihood: -1033.5219277413703
# Epoch 44600 Train loglikelihood: -3715.7387372155963
# Validation likelihood: -1046.3542441443583
# Epoch 44700 Train loglikelihood: -3765.194247323734
# Validation likelihood: -1041.2851912283768
# Epoch 44800 Train loglikelihood: -3666.4428824709694
# Validation likelihood: -1022.6257205913831
# Epoch 44900 Train loglikelihood: -3634.4078932078264
# Validation likelihood: -1014.9967253374729
# Epoch 45000 Train loglikelihood: -4309.47924619612
# Validation likelihood: -1102.2024316461811
# Epoch 45100 Train loglikelihood: -3682.7685210909813
# Validation likelihood: -1021.975986600449
# Epoch 45200 Train loglikelihood: -3558.479283473559
# Validation likelihood: -1030.8886492659997
# Epoch 45300 Train loglikelihood: -3659.7726512765876
# Validation likelihood: -997.7906163736344
# Scatter sampling
# Sampling from dim: 1
# Epoch 45400 Train loglikelihood: -3763.4216163858264
# Validation likelihood: -1048.8539280358655
# Epoch 45500 Train loglikelihood: -3639.504004396107
# Validation likelihood: -1014.8109397492543
# Epoch 45600 Train loglikelihood: -3565.4083081220047
# Validation likelihood: -1017.6386759753566
# Epoch 45700 Train loglikelihood: -3600.0288685580135
# Validation likelihood: -994.8201149940478
# Scatter sampling
# Sampling from dim: 1
# Epoch 45800 Train loglikelihood: -3643.864122151674
# Validation likelihood: -1002.3137701228994
# Epoch 45900 Train loglikelihood: -3570.6689600371774
# Validation likelihood: -1008.5029027222495
# Epoch 46000 Train loglikelihood: -3619.8939493726048
# Validation likelihood: -989.9394420419984
# Scatter sampling
# Sampling from dim: 1
# Epoch 46100 Train loglikelihood: -3816.189293602362
# Validation likelihood: -1048.5880201100185
# Epoch 46200 Train loglikelihood: -3483.337810303441
# Validation likelihood: -984.9160868404131
# Scatter sampling
# Sampling from dim: 1
# Epoch 46300 Train loglikelihood: -3507.219714832464
# Validation likelihood: -1035.2940313198255
# Epoch 46400 Train loglikelihood: -3462.025958232899
# Validation likelihood: -994.1280314049793
# Epoch 46500 Train loglikelihood: -3471.646344629822
# Validation likelihood: -986.424942562365
# Epoch 46600 Train loglikelihood: -3432.0237391210235
# Validation likelihood: -989.0127199781074
# Epoch 46700 Train loglikelihood: -3632.0860997764607
# Validation likelihood: -1015.8414990594604
# Epoch 46800 Train loglikelihood: -3410.3084615463627
# Validation likelihood: -990.1997415229939
# Epoch 46900 Train loglikelihood: -4399.959756258647
# Validation likelihood: -1094.4891255726627
# Epoch 47000 Train loglikelihood: -3583.9049310718246
# Validation likelihood: -998.5547369649197
# Epoch 47100 Train loglikelihood: -3522.1081838345112
# Validation likelihood: -978.2770673595775
# Scatter sampling
# Sampling from dim: 1
# Epoch 47200 Train loglikelihood: -3773.9273813449277
# Validation likelihood: -994.7045289971405
# Epoch 47300 Train loglikelihood: -3396.555030962709
# Validation likelihood: -963.7075124430702
# Scatter sampling
# Sampling from dim: 1
# Epoch 47400 Train loglikelihood: -3609.4950692710768
# Validation likelihood: -991.0095025772114
# Epoch 47500 Train loglikelihood: -3367.6985083478653
# Validation likelihood: -969.8491161336955
# Epoch 47600 Train loglikelihood: -3399.124327927102
# Validation likelihood: -995.4258640698123
# Epoch 47700 Train loglikelihood: -3333.3480366479325
# Validation likelihood: -966.771274921786
# Epoch 47800 Train loglikelihood: -3617.5812008657413
# Validation likelihood: -1187.5701724620849
# Epoch 47900 Train loglikelihood: -3346.6813698432525
# Validation likelihood: -962.100576439432
# Scatter sampling
# Sampling from dim: 1
# Epoch 48000 Train loglikelihood: -3439.5164681733604
# Validation likelihood: -962.9862321917718
# Epoch 48100 Train loglikelihood: -3329.376556515167
# Validation likelihood: -958.2358978542413
# Scatter sampling
# Sampling from dim: 1
# Epoch 48200 Train loglikelihood: -3440.467915164789
# Validation likelihood: -958.9296403316538
# Epoch 48300 Train loglikelihood: -3392.44757936946
# Validation likelihood: -952.3572566489966
# Scatter sampling
# Sampling from dim: 1
# Epoch 48400 Train loglikelihood: -3462.1254012049703
# Validation likelihood: -974.4047883606829
# Epoch 48500 Train loglikelihood: -3305.5077012637043
# Validation likelihood: -947.7977810321818
# Scatter sampling
# Sampling from dim: 1
# Epoch 48600 Train loglikelihood: -3529.1526221978684
# Validation likelihood: -1053.3752375713004
# Epoch 48700 Train loglikelihood: -3301.4870087157474
# Validation likelihood: -940.3291945466738
# Scatter sampling
# Sampling from dim: 1
# Epoch 48800 Train loglikelihood: -3541.509223922392
# Validation likelihood: -963.4886198474312
# Epoch 48900 Train loglikelihood: -3386.9376726827186
# Validation likelihood: -958.3855309673186
# Epoch 49000 Train loglikelihood: -3387.0409748713564
# Validation likelihood: -1055.8921597115445
# Epoch 49100 Train loglikelihood: -3659.5148431489965
# Validation likelihood: -946.6643411891413
# Epoch 49200 Train loglikelihood: -3379.0423665866065
# Validation likelihood: -955.8479597137928
# Epoch 49300 Train loglikelihood: -3277.0815328580325
# Validation likelihood: -940.8058347496158
# Epoch 49400 Train loglikelihood: -3330.699159586923
# Validation likelihood: -1003.1512917038622
# Epoch 49500 Train loglikelihood: -3373.1029111526705
# Validation likelihood: -1013.3884734705258
# Epoch 49600 Train loglikelihood: -3222.3092728897964
# Validation likelihood: -955.1381298204478
# Epoch 49700 Train loglikelihood: -3346.659954551472
# Validation likelihood: -930.4370029104716
# Scatter sampling
# Sampling from dim: 1
# Epoch 49800 Train loglikelihood: -3368.6853326481305
# Validation likelihood: -940.4058636778133
# Epoch 49900 Train loglikelihood: -3208.0657668723443
# Validation likelihood: -928.1325217514574
# Scatter sampling
# Sampling from dim: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 107
#     105 optimizer.zero_grad()
#     106 model.phi.resample_M(200)
# --> 107 logloss = model(covariate_tensor_train, times_tensor_train, event_indicator_tensor_train, max_iter = 10000,selected_indicators=[1,3,5])
#     108 # scaleloss = torch.square(torch.mean(model.phi.M)-1)
#     109 # reg_loss = logloss+scaleloss
#     110 (-logloss).backward()
#
# File ~/anaconda3/envs/DCSurvival/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/HACSurv_Github_2march/survival.py:1253, in HACSurv_3D_Sym_shared.forward(self, x, t, c, max_iter, selected_indicators)
#    1250 censoring_log_density = torch.log(density_C).squeeze()
#    1252 # 验证生存函数是否在[0, 1]之间
# -> 1253 assert (S_E1 >= 0.).all() and (S_E1 <= 1. + 1e-10).all(), "t %s, output %s" % (t, S_E1)
#    1254 assert (S_E2 >= 0.).all() and (S_E2 <= 1. + 1e-10).all(), "t %s, output %s" % (t, S_E2)
#    1255 assert (S_C >= 0.).all() and (S_C <= 1. + 1e-10).all(), "t %s, output %s" % (t, S_C)
#
# KeyboardInterrupt:

# %%
##训练inner
## 应该学习两个inner， 135和24
from torch.utils.data import TensorDataset, DataLoader
from survival import sample,Copula,HACSurv_2D_shared,HACSurv_3D_Sym_shared
def sampleInner(phi, ndims, n, M0=None):
    device = phi.mu.device  # 获取phi.mu的设备，确保所有操作都在同一设备上进行
    
    if M0 is None:
        M0 = phi.psi.sample_M(n).to(device)  # 确保M0在正确的设备上
    
    njumps = torch.poisson(torch.exp(phi.beta) * M0).int()
    
    # 确保c也在同一个设备
    c = torch.tensor([phi.sample_M(njumps[i].item()).sum() for i in range(n)], device=device)
    
    lso = torch.exp(phi.mu) * M0 + c  # 现在phi.mu, M0和c都在同一个设备上
    
    M = lso[:, None].expand(-1, ndims)
    e = torch.distributions.exponential.Exponential(torch.ones((n, ndims), device=device))  # 确保指数分布也在同一设备上
    E = e.sample()
    
    return phi.forward(E / M)
# 固定随机数种子
torch.set_default_tensor_type(torch.DoubleTensor)
phi = MixExpPhiStochastic(device)
# selected_indicators = [0,1]
##学习24
# model =HACSurv_2D_shared(phi, device = device, num_features=x_train.shape[1], tol=1e-10, hidden_size = 100).to(device)
#学习135
model =HACSurv_3D_Sym_shared(phi, device = device, num_features=x_train.shape[1], tol=1e-14, hidden_size = 100).to(device)

print(device)
#要学习的inner的copula参数
checkpoint = torch.load('./MIMIC-III/checkpoint/MIMIC_e135_sharedHACSurv.pth')
model.load_state_dict(checkpoint['model_state_dict'])

model.phi.resample_M(200)
samples = sample(model, 2, 5000, device =  device)
# print(samples.shape)
num_train_samples = 4000
num_test_samples = 1000  # 或者通过 samples.shape[0] - num_train_samples 计算得到


plt.scatter(samples[:, 0].cpu(), samples[:, 1].cpu(), s=15)
# os.makedirs('/home/liuxin/GenACSurvival-main/sample_figs/'+copula_form+'/'+str(theta_true), exist_ok=True)
plt.savefig('./MIMIC-III/figure/HACMIMIC_135.png' )


# 分割样本
train_data = samples[:num_train_samples]
test_data = samples[num_train_samples:num_train_samples + num_test_samples]
psi = MixExpPhiStochastic(device)
#选取outer copula
ckpt_path_out = './MIMIC-III/checkpoint/MIMIC_e05.pth'
    
ckpt_out = torch.load(ckpt_path_out)
        # # # print(ckpt_out)
        
phi_out_keys = {k.replace('phi.', ''): v for k, v in ckpt_out['model_state_dict'].items() if 'phi' in k and 'phi_inv' not in k}
psi.load_state_dict(phi_out_keys)  



psi_cop = Copula(psi,device)

phi = InnerGenerator(psi,device)
net = Copula(phi,device)
optim_args = \
    {
        'lr': 1e-5, # it is 1e-3 since torch.sum was used instead of torch.mean for loglikelihood
        'momentum': 0.9
    }

optimizer = optim.SGD(net.parameters(), optim_args['lr'], optim_args['momentum'])
num_epochs = 10000
batch_size = 4000
chkpt_freq = 500
patience = 1000
best_val_loss = np.inf
epochs_no_improve = 0
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1000000, shuffle=True)
    
train_loss_per_epoch = []
# print('1')
for epoch in range(num_epochs):
        # print(epoch)
        loss_per_minibatch = []
        for i, data in enumerate(train_loader, 0):
            optimizer.zero_grad()

            if hasattr(net.phi.psi, 'resample_M'):
                net.phi.psi.resample_M(100)
            net.phi.resample_M(100)

            d = data.detach().clone().to(device)
            p = net(d, mode='pdf')
            # print('2')
            scaleloss = torch.square(torch.mean(net.phi.M)-1)
            logloss = -torch.sum(torch.log(p))
            reg_loss = logloss+scaleloss
            reg_loss.backward()
            # loss_per_minibatch.append((logloss / p.numel()).detach().cpu().numpy())
            # loss_per_minibatch.append((logloss/p.numel()).detach().numpy())
            optimizer.step()

        # train_loss_per_epoch.append(np.mean(loss_per_minibatch))

        # 验证集性能评估
        if epoch % 100 == 0:
            val_logloss = 0
            for i, data in enumerate(test_loader, 0):
                if hasattr(net.phi.psi, 'resample_M'):
                    net.phi.psi.resample_M(1000)
                net.phi.resample_M(1000)
                d = data.detach().clone().to(device)
                p = net(d, mode='pdf')
                val_logloss += -torch.mean(torch.log(p)).item()
            val_logloss /= len(test_loader)

            # 更新最佳模型
            if val_logloss < best_val_loss:
                best_val_loss = val_logloss
                epochs_no_improve = 0
                # 保存模型状态
                checkpoint_path = os.path.join('./MIMIC-III/checkpoint', 'Model_inner_e1e3e5_step2_05outer.pth')
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': net.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': val_logloss,
                }, checkpoint_path)

                # 生成并保存样本图像
                samples = sampleInner(net.phi, 2, 5000).detach().cpu()
                plt.scatter(samples[:, 0], samples[:, 1],s=15)
                # plt.axis("square")
                plot_path = os.path.join('./MIMIC-III/figure', 'Model_inner_e1e3e5_step2_05outer.png')
                plt.savefig(plot_path)
                plt.clf()

                print('Epoch {}: Train {}, Val {}'.format(epoch, reg_loss.item(), val_logloss))
            else:
                epochs_no_improve += 100

            # 早停检查
            if epochs_no_improve >= patience:
                print('Early stopping triggered at epoch:', epoch)
                break
# Out:
# cuda:1
# Sampling from dim: 1
# Epoch 0: Train -423.20985593340436, Val -0.08711694476418459
# Epoch 100: Train -520.6144569841939, Val -0.12144183278371501
# Epoch 200: Train -1580.2365629492901, Val -0.42484742569839906
# Epoch 300: Train -2221.446200764324, Val -0.5684877581758566
# Epoch 400: Train -2542.0710500220607, Val -0.6133586408909045
# Epoch 500: Train -2558.506074953206, Val -0.6294615030640216
# Epoch 600: Train -2575.3783541036228, Val -0.6534670908730695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 95
#      92 net.phi.resample_M(100)
#      94 d = data.detach().clone().to(device)
# ---> 95 p = net(d, mode='pdf')
#      96 # print('2')
#      97 scaleloss = torch.square(torch.mean(net.phi.M)-1)
#
# File ~/anaconda3/envs/DCSurvival/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/HACSurv_Github_2march/survival.py:518, in Copula.forward(self, y, mode, others, tol)
#     516     cur = cdf
#     517     for dim in range(ndims):
# --> 518         cur = torch.autograd.grad(
#     519             cur.sum(), y, create_graph=True)[0][:, dim].to(self.device)
#     520     return cur
#     522 if mode == 'pdf2':
#
# File ~/anaconda3/envs/DCSurvival/lib/python3.9/site-packages/torch/autograd/__init__.py:276, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     274     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     275 else:
# --> 276     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     277         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     278         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:
